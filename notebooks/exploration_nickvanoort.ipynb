# %%
# Importing necessary libraries
import pandas as pd

import os

# Check current working directory
print(os.getcwd())

# Set working directory to project root if needed
os.chdir('C:/Users/NvanOort/Projects/MADS/DATEXP/workshop-collaboration')
# Out:
# c:\Users\NvanOort\Projects\MADS\DATEXP\workshop-collaboration\notebooks

# %%
# Loading the data
df = pd.read_csv('./data/raw/correlation_jngdc.csv')
df
# Out:
#      Unnamed: 0      target         0         1         2         3         4  \
# 0             0  -33.649387  0.485653  0.901637 -1.212651  0.139052  0.709391
# 1             1  120.201493 -0.893088 -0.071643  0.009755  1.347144  0.379104
# 2             2 -141.708704  0.456587 -0.472096  1.606499  1.367399 -0.073593
# 3             3 -184.095636 -0.765121 -0.938719 -0.854190  0.131660 -0.414848
# 4             4  246.179468 -0.382082  0.026456  2.268877  0.527533 -0.053195
# ..          ...         ...       ...       ...       ...       ...       ...
# 495         495  -47.645625  0.270316 -0.414474 -0.998558 -0.315235 -0.528897
# 496         496  -97.823612 -1.860027  0.694745  0.150319 -0.272093  0.974670
# 497         497   18.574557  0.245938  0.181293 -0.426479 -0.528526 -1.171791
# 498         498  318.199756 -0.113337 -0.417187  0.416573  0.092562  1.975764
# 499         499  160.566505 -0.308673 -0.542890  1.151007 -0.357230  1.173319
#
# ...

# %%
# Checking general information about the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Columns: 102 entries, Unnamed: 0 to 99
# dtypes: float64(101), int64(1)
# memory usage: 398.6 KB

# %%
# Looking at general statastics of the data
df.describe()
# Out:
#        Unnamed: 0      target           0           1           2           3  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean   249.500000   -0.882341    0.040909   -0.044409    0.015326   -0.002659
# std    144.481833  160.922949    0.995599    1.038941    1.027452    1.002333
# min      0.000000 -485.914105   -3.295622   -3.404040   -3.055395   -3.006454
# 25%    124.750000 -108.942259   -0.619451   -0.747889   -0.744192   -0.655444
# 50%    249.500000   -9.114029    0.024301    0.019376    0.022804   -0.018949
# 75%    374.250000  117.389754    0.723823    0.594201    0.724441    0.637174
# max    499.000000  456.485770    2.969883    3.736603    2.595107    2.849739
#
#                 4           5           6           7  ...          90  \
# count  500.000000  500.000000  500.000000  500.000000  ...  500.000000
# mean    -0.025269   -0.032729   -0.000622   -0.058377  ...   -0.016439
# ...

# %%
# Calculate the correlation matrix
corr_matrix = df.corr()['target']

# Get the top 5 strongest correlations
top_5_corr = corr_matrix.abs().nlargest(5)

# Print the top 5 strongest correlations
print(top_5_corr)
# Out:
# target    1.000000
# 99        0.776946
# 92        0.583112
# 51        0.490532
# 58        0.334788
# Name: target, dtype: float64
